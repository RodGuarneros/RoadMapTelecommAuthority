# %%
import pandas as pd
import numpy as np
import plotly as plt
import plotly.graph_objects as go

# %%
# Reading files

portafolio = pd.read_csv("Portafolio20.09.21.csv", encoding="Latin1")
ces = pd.read_csv("CES.csv", encoding="Latin1")

# %%
ces_nuevos=ces[ces['ID']==0]
ces_nuevos
# Out:
#     ID                                             Nombre LARs  \
# 18   0  (Adopción y uso de las TIC en los establecimie...  CES
# 19   0  Análisis del costo promedio ponderado del capi...  NaN
# 21   0  El empaquetamiento de servicios de telecomunic...  NaN
# 22   0  Revisión de la teoría del daño en el contexto ...  NaN
#
#    Proyecto Actividad Área Responsable  Ejecución  Puntuación  \
# 18               2021              NaN       2021         NaN
# 19                NaN              CES       2022         NaN
# 21                NaN              CES       2022         NaN
# 22                NaN              CES       2022         NaN
#
#    ¿Ha sido concluido el proyecto o actividad?  \
# 18                                          Sí
# 19                                          No
# 21                                          No
# 22                                          No
#
#    Mes y año tentativo de terminación del proyecto o actividad \n(mm/aa)  \
# ...

# %%
portafolio.dtypes
# Out:
# ID                          int64
# Objetivos                  object
# Estrategias                object
# LARs                       object
# LAR                        object
#                            ...
# Puntuación Final          float64
# Detalle_deadline           object
# Meta 2022                 float64
# PAT 2022                   object
# ¿Proviene de PAT 2021?     object
# Length: 70, dtype: object

# %%
portafolio.set_index('ID', inplace=True)
ces.set_index('ID', inplace=True)

# %%
ces.dtypes
# Out:
# ID                                                                         int64
# Nombre                                                                    object
# LARs                                                                      object
# Proyecto Actividad                                                        object
# Área Responsable                                                          object
# Ejecución                                                                  int64
# Puntuación                                                               float64
# ¿Ha sido concluido el proyecto o actividad?                               object
# Mes y año tentativo de terminación del proyecto o actividad \n(mm/aa)     object
# Nombre completo del responsable del proyecto                              object
# Porcentaje de avance al momento de atención a este reporte (0-100%)       object
# Comentarios                                                               object
# ...

# %%
portafolio
# Out:
#                                          Objetivos     Estrategias  \
# ID
# 1                             Objetivo Transversal  Estrategia T.1
# 2                         Objetivo 2 (Competencia)  Estrategia 2.1
# 3                             Objetivo Transversal  Estrategia T.1
# 4    Objetivo 4 (Protección, Calidad y Pluralidad)  Estrategia 4.4
# 5                         Objetivo 2 (Competencia)  Estrategia 2.1
# ..                                             ...             ...
# 229                           Objetivo Transversal  Estrategia T.1
# 230                           Objetivo Transversal  Estrategia T.2
# 231                           Objetivo Transversal  Estrategia T.2
# 232                           Objetivo Transversal  Estrategia T.2
# 233                           Objetivo Transversal  Estrategia T.2
#
#                                                   LARs        LAR  \
# ID
# 1    LAR T.1.6: Revisar las regulaciones, marco nor...  LAR T.1.6
# ...

# %%
# Obteniendo las actividades o proyectos nuevos index=0 de origen
ces.filter(items = [0], axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-4aec4723098e> in <module>
#       1 # Obteniendo las actividades o proyectos nuevos index=0 de origen
# ----> 2 ces.filter(items = [0], axis=0)
#
# ~\Anaconda4\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4974         if items is not None:
#    4975             name = self._get_axis_name(axis)
# -> 4976             return self.reindex(**{name: [r for r in items if r in labels]})
#    4977         elif like:
#    4978
#
# ~\Anaconda4\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     310         @wraps(func)
#     311         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 312             return func(*args, **kwargs)
#     313
#     314         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ...

# %%
ces
# Out:
#                                                 Nombre  \
# ID
# 32   Análisis de las iniciativas públicas y privada...
# 48   Análisis del impacto de la política fiscal sob...
# 52       Reporte sobre Sandbox regulatorio para el IFT
# 53   Análisis y evaluación de las alternativas tecn...
# 56   Análisis del impacto de la tecnología 5G en la...
# 61   Estudio sobre el uso eficiente del espectro: m...
# 63   Reporte de factores que explican la evolución ...
# 85   Estudio de la convergencia de los servicios de...
# 86   Elementos para adaptación de la guía de concen...
# 88   Estudio del estado de la compartición de infra...
# 91   Análisis de la concentración en las telecomuni...
# 95   Consideraciones de eficiencia de los mecanismo...
# 111  La Ciberseguridad como habilitador de la trans...
# 113  Estudio sobre la evolución hacia el bienestar ...
# 126  Analizar estrategias y alternativas para impul...
# 157  Cuaderno guía para la evaluación ex post de me...
# ...
